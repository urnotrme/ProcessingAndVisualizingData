# %% [markdown]
# Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Create a bar chart

# %%
data = [24, 22, 20,14]
ds2 = pd.Series(data)
ds2.index = ['Novak Djokovic','Rafael Nadal','Roger Federe','Pete Sampras']
ds2.plot(kind='bar', title="Grand Slam tournaments", xlabel='Titles')
# Out:
# <Axes: title={'center': 'Grand Slam tournaments'}, xlabel='Titles'>
